# %%
import os
import numpy as np
import glob

# Set your dataset root and output path
DATASET_ROOT = "Stanford3dDataset_v1.2"
OUTPUT_ROOT = "processed_data"

# Define label mapping
CLASSES = [
    "ceiling", "floor", "wall", "beam", "column", "window",
    "door", "table", "chair", "sofa", "bookcase", "board", "clutter"
]
class2label = {cls: i for i, cls in enumerate(CLASSES)}

# %%
def parse_room(area_split, room_name, angle, align_angle=True, normalize=True):
    print(f"🔍 Parsing room: {room_name}")
    
    room_path = os.path.join(DATASET_ROOT, area_split, room_name)
    annotation_path = os.path.join(room_path, "Annotations")
    files = sorted(glob.glob(os.path.join(annotation_path, "*.txt")))

    if not files:
        print(f"⚠️ No annotation files in {annotation_path}")
        return None, None, None, None

    coords, colors, segment, instance = [], [], [], []

    for object_id, file in enumerate(files):
        class_name = os.path.basename(file).split("_")[0]
        label = class2label.get(class_name, class2label["clutter"])
        
        data = np.loadtxt(file)
        coords.append(data[:, :3])
        colors.append(data[:, 3:6] / 255.0)  # scale RGB to 0–1
        segment.append(np.full((data.shape[0], 1), label))
        instance.append(np.full((data.shape[0], 1), object_id))

    coords = np.vstack(coords)
    colors = np.vstack(colors)
    segment = np.vstack(segment)
    instance = np.vstack(instance)

    # Align coordinates using angle file
    if align_angle and angle is not None:
        angle_rad = (2 - angle / 180) * np.pi
        rot_cos, rot_sin = np.cos(angle_rad), np.sin(angle_rad)
        rot_matrix = np.array([
            [rot_cos, -rot_sin, 0],
            [rot_sin, rot_cos, 0],
            [0, 0, 1]
        ])
        room_center = (np.max(coords, axis=0) + np.min(coords, axis=0)) / 2
        coords = (coords - room_center) @ rot_matrix.T + room_center

    # ✅ Normalize coordinates
    if normalize:
        coords_mean = np.mean(coords, axis=0)
        coords_std = np.std(coords, axis=0)
        coords = (coords - coords_mean) / coords_std

    return coords, colors, segment, instance

# %%
areas = ["Area_1", "Area_2", "Area_3", "Area_4", "Area_5", "Area_6"]

for area in areas:
    angle_file = os.path.join(DATASET_ROOT, area, f"{area}_alignmentAngle.txt")
    
    room_names, room_angles = [], []
    with open(angle_file, "r") as f:
        for line in f:
            parts = line.strip().split()
            if len(parts) == 2:
                room_names.append(parts[0])
                room_angles.append(int(parts[1]))

    for room_name, angle in zip(room_names, room_angles):
        result = parse_room(area, room_name, angle, align_angle=True, normalize=True)
        if result[0] is None:
            continue
        
        coords, colors, segment, instance = result
        save_path = os.path.join(OUTPUT_ROOT, area, room_name)
        os.makedirs(save_path, exist_ok=True)

        np.save(os.path.join(save_path, "coord.npy"), coords.astype(np.float32))
        np.save(os.path.join(save_path, "color.npy"), (colors * 255).astype(np.uint8))
        np.save(os.path.join(save_path, "segment.npy"), segment.astype(np.int16))
        np.save(os.path.join(save_path, "instance.npy"), instance.astype(np.int16))

        print(f"✔ Saved: {area}/{room_name}")
# Out:
# 🔍 Parsing room: conferenceRoom_1
# ✔ Saved: Area_1/conferenceRoom_1
# 🔍 Parsing room: conferenceRoom_2
# ✔ Saved: Area_1/conferenceRoom_2
# 🔍 Parsing room: copyRoom_1
# ✔ Saved: Area_1/copyRoom_1
# 🔍 Parsing room: hallway_1
# ✔ Saved: Area_1/hallway_1
# 🔍 Parsing room: hallway_2
# ✔ Saved: Area_1/hallway_2
# 🔍 Parsing room: hallway_3
# ✔ Saved: Area_1/hallway_3
# 🔍 Parsing room: hallway_4
# ✔ Saved: Area_1/hallway_4
# 🔍 Parsing room: hallway_5
# ✔ Saved: Area_1/hallway_5
# 🔍 Parsing room: hallway_6
# ✔ Saved: Area_1/hallway_6
# 🔍 Parsing room: hallway_7
# ✔ Saved: Area_1/hallway_7
# 🔍 Parsing room: hallway_8
# ✔ Saved: Area_1/hallway_8
# 🔍 Parsing room: office_1
# ✔ Saved: Area_1/office_1
# 🔍 Parsing room: office_2
# ✔ Saved: Area_1/office_2
# 🔍 Parsing room: office_3
# ✔ Saved: Area_1/office_3
# 🔍 Parsing room: office_4
# ✔ Saved: Area_1/office_4
# 🔍 Parsing room: office_5
# ✔ Saved: Area_1/office_5
# 🔍 Parsing room: office_6
# ✔ Saved: Area_1/office_6
# 🔍 Parsing room: office_7
# ✔ Saved: Area_1/office_7
# 🔍 Parsing room: office_8
# ✔ Saved: Area_1/office_8
# 🔍 Parsing room: office_9
# ✔ Saved: Area_1/office_9
# 🔍 Parsing room: office_10
# ✔ Saved: Area_1/office_10
# 🔍 Parsing room: office_11
# ✔ Saved: Area_1/office_11
# 🔍 Parsing room: office_12
# ✔ Saved: Area_1/office_12
# 🔍 Parsing room: office_13
# ✔ Saved: Area_1/office_13
# 🔍 Parsing room: office_14
# ✔ Saved: Area_1/office_14
# 🔍 Parsing room: office_15
# ✔ Saved: Area_1/office_15
# 🔍 Parsing room: office_16
# ✔ Saved: Area_1/office_16
# 🔍 Parsing room: office_17
# ✔ Saved: Area_1/office_17
# 🔍 Parsing room: office_18
# ✔ Saved: Area_1/office_18
# 🔍 Parsing room: office_19
# ✔ Saved: Area_1/office_19
# 🔍 Parsing room: office_20
# ✔ Saved: Area_1/office_20
# 🔍 Parsing room: office_21
# ✔ Saved: Area_1/office_21
# 🔍 Parsing room: office_22
# ✔ Saved: Area_1/office_22
# 🔍 Parsing room: office_23
# ✔ Saved: Area_1/office_23
# 🔍 Parsing room: office_24
# ✔ Saved: Area_1/office_24
# 🔍 Parsing room: office_25
# ✔ Saved: Area_1/office_25
# 🔍 Parsing room: office_26
# ✔ Saved: Area_1/office_26
# 🔍 Parsing room: office_27
# ✔ Saved: Area_1/office_27
# 🔍 Parsing room: office_28
# ✔ Saved: Area_1/office_28
# 🔍 Parsing room: office_29
# ✔ Saved: Area_1/office_29
# 🔍 Parsing room: office_30
# ✔ Saved: Area_1/office_30
# 🔍 Parsing room: office_31
# ✔ Saved: Area_1/office_31
# 🔍 Parsing room: pantry_1
# ✔ Saved: Area_1/pantry_1
# 🔍 Parsing room: WC_1
# ✔ Saved: Area_1/WC_1
# 🔍 Parsing room: auditorium_1
# ✔ Saved: Area_2/auditorium_1
# 🔍 Parsing room: auditorium_2
# ✔ Saved: Area_2/auditorium_2
# 🔍 Parsing room: conferenceRoom_1
# ✔ Saved: Area_2/conferenceRoom_1
# 🔍 Parsing room: hallway_1
# ✔ Saved: Area_2/hallway_1
# 🔍 Parsing room: hallway_2
# ✔ Saved: Area_2/hallway_2
# 🔍 Parsing room: hallway_3
# ✔ Saved: Area_2/hallway_3
# 🔍 Parsing room: hallway_4
# ✔ Saved: Area_2/hallway_4
# 🔍 Parsing room: hallway_5
# ✔ Saved: Area_2/hallway_5
# 🔍 Parsing room: hallway_6
# ✔ Saved: Area_2/hallway_6
# 🔍 Parsing room: hallway_7
# ✔ Saved: Area_2/hallway_7
# 🔍 Parsing room: hallway_8
# ✔ Saved: Area_2/hallway_8
# 🔍 Parsing room: hallway_9
# ✔ Saved: Area_2/hallway_9
# 🔍 Parsing room: hallway_10
# ✔ Saved: Area_2/hallway_10
# 🔍 Parsing room: hallway_11
# ✔ Saved: Area_2/hallway_11
# 🔍 Parsing room: hallway_12
# ✔ Saved: Area_2/hallway_12
# 🔍 Parsing room: office_1
# ✔ Saved: Area_2/office_1
# 🔍 Parsing room: office_2
# ✔ Saved: Area_2/office_2
# 🔍 Parsing room: office_3
# ✔ Saved: Area_2/office_3
# 🔍 Parsing room: office_4
# ✔ Saved: Area_2/office_4
# 🔍 Parsing room: office_5
# ✔ Saved: Area_2/office_5
# 🔍 Parsing room: office_6
# ✔ Saved: Area_2/office_6
# 🔍 Parsing room: office_7
# ✔ Saved: Area_2/office_7
# 🔍 Parsing room: office_8
# ✔ Saved: Area_2/office_8
# 🔍 Parsing room: office_9
# ✔ Saved: Area_2/office_9
# 🔍 Parsing room: office_10
# ✔ Saved: Area_2/office_10
# 🔍 Parsing room: office_11
# ✔ Saved: Area_2/office_11
# 🔍 Parsing room: office_12
# ✔ Saved: Area_2/office_12
# 🔍 Parsing room: office_13
# ✔ Saved: Area_2/office_13
# 🔍 Parsing room: office_14
# ✔ Saved: Area_2/office_14
# 🔍 Parsing room: storage_1
# ✔ Saved: Area_2/storage_1
# 🔍 Parsing room: storage_2
# ✔ Saved: Area_2/storage_2
# 🔍 Parsing room: storage_3
# ✔ Saved: Area_2/storage_3
# 🔍 Parsing room: storage_4
# ✔ Saved: Area_2/storage_4
# 🔍 Parsing room: storage_5
# ✔ Saved: Area_2/storage_5
# 🔍 Parsing room: storage_6
# ✔ Saved: Area_2/storage_6
# 🔍 Parsing room: storage_7
# ✔ Saved: Area_2/storage_7
# 🔍 Parsing room: storage_8
# ✔ Saved: Area_2/storage_8
# 🔍 Parsing room: storage_9
# ✔ Saved: Area_2/storage_9
# 🔍 Parsing room: WC_1
# ✔ Saved: Area_2/WC_1
# 🔍 Parsing room: WC_2
# ✔ Saved: Area_2/WC_2
# 🔍 Parsing room: conferenceRoom_1
# ✔ Saved: Area_3/conferenceRoom_1
# 🔍 Parsing room: hallway_1
# ✔ Saved: Area_3/hallway_1
# 🔍 Parsing room: hallway_2
# ✔ Saved: Area_3/hallway_2
# 🔍 Parsing room: hallway_3
# ✔ Saved: Area_3/hallway_3
# 🔍 Parsing room: hallway_4
# ✔ Saved: Area_3/hallway_4
# 🔍 Parsing room: hallway_5
# ✔ Saved: Area_3/hallway_5
# 🔍 Parsing room: hallway_6
# ✔ Saved: Area_3/hallway_6
# 🔍 Parsing room: lounge_1
# ✔ Saved: Area_3/lounge_1
# 🔍 Parsing room: lounge_2
# ✔ Saved: Area_3/lounge_2
# 🔍 Parsing room: office_1
# ✔ Saved: Area_3/office_1
# 🔍 Parsing room: office_2
# ✔ Saved: Area_3/office_2
# 🔍 Parsing room: office_3
# ✔ Saved: Area_3/office_3
# 🔍 Parsing room: office_4
# ✔ Saved: Area_3/office_4
# 🔍 Parsing room: office_5
# ✔ Saved: Area_3/office_5
# 🔍 Parsing room: office_6
# ✔ Saved: Area_3/office_6
# 🔍 Parsing room: office_7
# ✔ Saved: Area_3/office_7
# 🔍 Parsing room: office_8
# ✔ Saved: Area_3/office_8
# 🔍 Parsing room: office_9
# ✔ Saved: Area_3/office_9
# 🔍 Parsing room: office_10
# ✔ Saved: Area_3/office_10
# 🔍 Parsing room: storage_1
# ✔ Saved: Area_3/storage_1
# 🔍 Parsing room: storage_2
# ✔ Saved: Area_3/storage_2
# 🔍 Parsing room: WC_1
# ✔ Saved: Area_3/WC_1
# 🔍 Parsing room: WC_2
# ✔ Saved: Area_3/WC_2
# 🔍 Parsing room: conferenceRoom_1
# ✔ Saved: Area_4/conferenceRoom_1
# 🔍 Parsing room: conferenceRoom_2
# ✔ Saved: Area_4/conferenceRoom_2
# 🔍 Parsing room: conferenceRoom_3
# ✔ Saved: Area_4/conferenceRoom_3
# 🔍 Parsing room: hallway_1
# ✔ Saved: Area_4/hallway_1
# 🔍 Parsing room: hallway_2
# ✔ Saved: Area_4/hallway_2
# 🔍 Parsing room: hallway_3
# ✔ Saved: Area_4/hallway_3
# 🔍 Parsing room: hallway_4
# ✔ Saved: Area_4/hallway_4
# 🔍 Parsing room: hallway_5
# ✔ Saved: Area_4/hallway_5
# 🔍 Parsing room: hallway_6
# ✔ Saved: Area_4/hallway_6
# 🔍 Parsing room: hallway_7
# ✔ Saved: Area_4/hallway_7
# 🔍 Parsing room: hallway_8
# ✔ Saved: Area_4/hallway_8
# 🔍 Parsing room: hallway_9
# ✔ Saved: Area_4/hallway_9
# 🔍 Parsing room: hallway_10
# ✔ Saved: Area_4/hallway_10
# 🔍 Parsing room: hallway_11
# ✔ Saved: Area_4/hallway_11
# 🔍 Parsing room: hallway_12
# ✔ Saved: Area_4/hallway_12
# 🔍 Parsing room: hallway_13
# ✔ Saved: Area_4/hallway_13
# 🔍 Parsing room: hallway_14
# ✔ Saved: Area_4/hallway_14
# 🔍 Parsing room: lobby_1
# ✔ Saved: Area_4/lobby_1
# 🔍 Parsing room: lobby_2
# ✔ Saved: Area_4/lobby_2
# 🔍 Parsing room: office_1
# ✔ Saved: Area_4/office_1
# 🔍 Parsing room: office_2
# ✔ Saved: Area_4/office_2
# 🔍 Parsing room: office_3
# ✔ Saved: Area_4/office_3
# 🔍 Parsing room: office_4
# ✔ Saved: Area_4/office_4
# 🔍 Parsing room: office_5
# ✔ Saved: Area_4/office_5
# 🔍 Parsing room: office_6
# ✔ Saved: Area_4/office_6
# 🔍 Parsing room: office_7
# ✔ Saved: Area_4/office_7
# 🔍 Parsing room: office_8
# ✔ Saved: Area_4/office_8
# 🔍 Parsing room: office_9
# ✔ Saved: Area_4/office_9
# 🔍 Parsing room: office_10
# ✔ Saved: Area_4/office_10
# 🔍 Parsing room: office_11
# ✔ Saved: Area_4/office_11
# 🔍 Parsing room: office_12
# ✔ Saved: Area_4/office_12
# 🔍 Parsing room: office_13
# ✔ Saved: Area_4/office_13
# 🔍 Parsing room: office_14
# ✔ Saved: Area_4/office_14
# 🔍 Parsing room: office_15
# ✔ Saved: Area_4/office_15
# 🔍 Parsing room: office_16
# ✔ Saved: Area_4/office_16
# 🔍 Parsing room: office_17
# ✔ Saved: Area_4/office_17
# 🔍 Parsing room: office_18
# ✔ Saved: Area_4/office_18
# 🔍 Parsing room: office_19
# ✔ Saved: Area_4/office_19
# 🔍 Parsing room: office_20
# ✔ Saved: Area_4/office_20
# 🔍 Parsing room: office_21
# ✔ Saved: Area_4/office_21
# 🔍 Parsing room: office_22
# ✔ Saved: Area_4/office_22
# 🔍 Parsing room: storage_1
# ✔ Saved: Area_4/storage_1
# 🔍 Parsing room: storage_2
# ✔ Saved: Area_4/storage_2
# 🔍 Parsing room: storage_3
# ✔ Saved: Area_4/storage_3
# 🔍 Parsing room: storage_4
# ✔ Saved: Area_4/storage_4
# 🔍 Parsing room: WC_1
# ✔ Saved: Area_4/WC_1
# 🔍 Parsing room: WC_2
# ✔ Saved: Area_4/WC_2
# 🔍 Parsing room: WC_3
# ✔ Saved: Area_4/WC_3
# 🔍 Parsing room: WC_4
# ✔ Saved: Area_4/WC_4
# 🔍 Parsing room: conferenceRoom_1
# ✔ Saved: Area_5/conferenceRoom_1
# 🔍 Parsing room: conferenceRoom_2
# ✔ Saved: Area_5/conferenceRoom_2
# 🔍 Parsing room: conferenceRoom_3
# ✔ Saved: Area_5/conferenceRoom_3
# 🔍 Parsing room: hallway_1
# ✔ Saved: Area_5/hallway_1
# 🔍 Parsing room: hallway_2
# ✔ Saved: Area_5/hallway_2
# 🔍 Parsing room: hallway_3
# ✔ Saved: Area_5/hallway_3
# 🔍 Parsing room: hallway_4
# ✔ Saved: Area_5/hallway_4
# 🔍 Parsing room: hallway_5
# ✔ Saved: Area_5/hallway_5
# 🔍 Parsing room: hallway_6
# ✔ Saved: Area_5/hallway_6
# 🔍 Parsing room: lobby_1
# ✔ Saved: Area_5/lobby_1
# 🔍 Parsing room: hallway_7
# ✔ Saved: Area_5/hallway_7
# 🔍 Parsing room: hallway_8
# ✔ Saved: Area_5/hallway_8
# 🔍 Parsing room: hallway_9
# ✔ Saved: Area_5/hallway_9
# 🔍 Parsing room: hallway_10
# ✔ Saved: Area_5/hallway_10
# 🔍 Parsing room: hallway_11
# ✔ Saved: Area_5/hallway_11
# 🔍 Parsing room: hallway_12
# ✔ Saved: Area_5/hallway_12
# 🔍 Parsing room: hallway_13
# ✔ Saved: Area_5/hallway_13
# 🔍 Parsing room: hallway_14
# ✔ Saved: Area_5/hallway_14
# 🔍 Parsing room: hallway_15
# ✔ Saved: Area_5/hallway_15
# 🔍 Parsing room: office_1
# ✔ Saved: Area_5/office_1
# 🔍 Parsing room: office_2
# ✔ Saved: Area_5/office_2
# 🔍 Parsing room: office_3
# ✔ Saved: Area_5/office_3
# 🔍 Parsing room: office_4
# ✔ Saved: Area_5/office_4
# 🔍 Parsing room: office_5
# ✔ Saved: Area_5/office_5
# 🔍 Parsing room: office_6
# ✔ Saved: Area_5/office_6
# 🔍 Parsing room: office_7
# ✔ Saved: Area_5/office_7
# 🔍 Parsing room: office_8
# ✔ Saved: Area_5/office_8
# 🔍 Parsing room: office_9
# ✔ Saved: Area_5/office_9
# 🔍 Parsing room: office_10
# ✔ Saved: Area_5/office_10
# 🔍 Parsing room: office_11
# ✔ Saved: Area_5/office_11
# 🔍 Parsing room: office_12
# ✔ Saved: Area_5/office_12
# 🔍 Parsing room: office_13
# ✔ Saved: Area_5/office_13
# 🔍 Parsing room: office_14
# ✔ Saved: Area_5/office_14
# 🔍 Parsing room: office_15
# ✔ Saved: Area_5/office_15
# 🔍 Parsing room: office_16
# ✔ Saved: Area_5/office_16
# 🔍 Parsing room: office_17
# ✔ Saved: Area_5/office_17
# 🔍 Parsing room: office_18
# ✔ Saved: Area_5/office_18
# 🔍 Parsing room: office_19
# ✔ Saved: Area_5/office_19
# 🔍 Parsing room: office_20
# ✔ Saved: Area_5/office_20
# 🔍 Parsing room: office_21
# ✔ Saved: Area_5/office_21
# 🔍 Parsing room: office_22
# ✔ Saved: Area_5/office_22
# 🔍 Parsing room: office_23
# ✔ Saved: Area_5/office_23
# 🔍 Parsing room: office_24
# ✔ Saved: Area_5/office_24
# 🔍 Parsing room: office_25
# ✔ Saved: Area_5/office_25
# 🔍 Parsing room: office_26
# ✔ Saved: Area_5/office_26
# 🔍 Parsing room: office_27
# ✔ Saved: Area_5/office_27
# 🔍 Parsing room: office_28
# ✔ Saved: Area_5/office_28
# 🔍 Parsing room: office_29
# ✔ Saved: Area_5/office_29
# 🔍 Parsing room: office_30
# ✔ Saved: Area_5/office_30
# 🔍 Parsing room: office_31
# ✔ Saved: Area_5/office_31
# 🔍 Parsing room: office_32
# ✔ Saved: Area_5/office_32
# 🔍 Parsing room: office_33
# ✔ Saved: Area_5/office_33
# 🔍 Parsing room: office_34
# ✔ Saved: Area_5/office_34
# 🔍 Parsing room: office_35
# ✔ Saved: Area_5/office_35
# 🔍 Parsing room: office_36
# ✔ Saved: Area_5/office_36
# 🔍 Parsing room: office_37
# ✔ Saved: Area_5/office_37
# 🔍 Parsing room: office_38
# ✔ Saved: Area_5/office_38
# 🔍 Parsing room: office_39
# ✔ Saved: Area_5/office_39
# 🔍 Parsing room: office_40
# ✔ Saved: Area_5/office_40
# 🔍 Parsing room: office_41
# ✔ Saved: Area_5/office_41
# 🔍 Parsing room: office_42
# ✔ Saved: Area_5/office_42
# 🔍 Parsing room: storage_1
# ✔ Saved: Area_5/storage_1
# 🔍 Parsing room: storage_2
# ✔ Saved: Area_5/storage_2
# 🔍 Parsing room: storage_3
# ✔ Saved: Area_5/storage_3
# 🔍 Parsing room: storage_4
# ✔ Saved: Area_5/storage_4
# 🔍 Parsing room: WC_1
# ✔ Saved: Area_5/WC_1
# 🔍 Parsing room: WC_2
# ✔ Saved: Area_5/WC_2
# 🔍 Parsing room: pantry_1
# ✔ Saved: Area_5/pantry_1
# 🔍 Parsing room: conferenceRoom_1
# ✔ Saved: Area_6/conferenceRoom_1
# 🔍 Parsing room: hallway_1
# ✔ Saved: Area_6/hallway_1
# 🔍 Parsing room: hallway_2
# ✔ Saved: Area_6/hallway_2
# 🔍 Parsing room: hallway_3
# ✔ Saved: Area_6/hallway_3
# 🔍 Parsing room: hallway_4
# ✔ Saved: Area_6/hallway_4
# 🔍 Parsing room: hallway_5
# ✔ Saved: Area_6/hallway_5
# 🔍 Parsing room: hallway_6
# ✔ Saved: Area_6/hallway_6
# 🔍 Parsing room: lounge_1
# ✔ Saved: Area_6/lounge_1
# 🔍 Parsing room: office_1
# ✔ Saved: Area_6/office_1
# 🔍 Parsing room: office_2
# ✔ Saved: Area_6/office_2
# 🔍 Parsing room: office_3
# ✔ Saved: Area_6/office_3
# 🔍 Parsing room: office_4
# ✔ Saved: Area_6/office_4
# 🔍 Parsing room: office_5
# ✔ Saved: Area_6/office_5
# 🔍 Parsing room: office_6
# ✔ Saved: Area_6/office_6
# 🔍 Parsing room: office_7
# ✔ Saved: Area_6/office_7
# 🔍 Parsing room: office_8
# ✔ Saved: Area_6/office_8
# 🔍 Parsing room: office_9
# ✔ Saved: Area_6/office_9
# 🔍 Parsing room: office_10
# ✔ Saved: Area_6/office_10
# 🔍 Parsing room: office_11
# ✔ Saved: Area_6/office_11
# 🔍 Parsing room: office_12
# ✔ Saved: Area_6/office_12
# 🔍 Parsing room: office_13
# ✔ Saved: Area_6/office_13
# 🔍 Parsing room: office_14
# ✔ Saved: Area_6/office_14
# 🔍 Parsing room: office_15
# ✔ Saved: Area_6/office_15
# 🔍 Parsing room: office_16
# ✔ Saved: Area_6/office_16
# 🔍 Parsing room: office_17
# ✔ Saved: Area_6/office_17
# 🔍 Parsing room: office_18
# ✔ Saved: Area_6/office_18
# 🔍 Parsing room: office_19
# ✔ Saved: Area_6/office_19
# 🔍 Parsing room: office_20
# ✔ Saved: Area_6/office_20
# 🔍 Parsing room: office_21
# ✔ Saved: Area_6/office_21
# 🔍 Parsing room: office_22
# ✔ Saved: Area_6/office_22
# 🔍 Parsing room: office_23
# ✔ Saved: Area_6/office_23
# 🔍 Parsing room: office_24
# ✔ Saved: Area_6/office_24
# 🔍 Parsing room: office_25
# ✔ Saved: Area_6/office_25
# 🔍 Parsing room: office_26
# ✔ Saved: Area_6/office_26
# 🔍 Parsing room: office_27
# ✔ Saved: Area_6/office_27
# 🔍 Parsing room: office_28
# ✔ Saved: Area_6/office_28
# 🔍 Parsing room: office_29
# ✔ Saved: Area_6/office_29
# 🔍 Parsing room: office_30
# ✔ Saved: Area_6/office_30
# 🔍 Parsing room: office_31
# ✔ Saved: Area_6/office_31
# 🔍 Parsing room: office_32
# ✔ Saved: Area_6/office_32
# 🔍 Parsing room: office_33
# ✔ Saved: Area_6/office_33
# 🔍 Parsing room: office_34
# ✔ Saved: Area_6/office_34
# 🔍 Parsing room: office_35
# ✔ Saved: Area_6/office_35
# 🔍 Parsing room: office_36
# ✔ Saved: Area_6/office_36
# 🔍 Parsing room: office_37
# ✔ Saved: Area_6/office_37
# 🔍 Parsing room: openspace_1
# ✔ Saved: Area_6/openspace_1
# 🔍 Parsing room: copyRoom_1
# ✔ Saved: Area_6/copyRoom_1
# 🔍 Parsing room: pantry_1
# ✔ Saved: Area_6/pantry_1
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
